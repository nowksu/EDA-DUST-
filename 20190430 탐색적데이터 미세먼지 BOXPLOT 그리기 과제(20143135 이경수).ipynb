# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt 
# %matplotlib inline #한글깨지는거 막기위해
url_1 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2014Q1.csv'
url_2 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2014Q2.csv'
url_3 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2014Q3.csv'
url_4 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2014Q4.csv'
url_5 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2015Q1.csv'
url_6 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2015Q2.csv'
url_7 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2015Q3.csv'
url_8 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2015Q4.csv'
url_9 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2016Q1.csv'
url_10 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2016Q2.csv'
url_11 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2016Q3.csv'
url_12 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2016Q4.csv'
url_13 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2017Q1.csv'
url_14 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2017Q2.csv'
url_15 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2017Q3.csv'
url_16 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2017Q4.csv'
url_17 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2018Q1.csv'
url_18 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2018Q2.csv'
url_19 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/2018Q3.csv'
url_20 ='http://wess.hannam.ac.kr/Stat_Notes/example_data/mise/201Q4.csv'
data_1 = pd.read_csv(url_1)
data_2 = pd.read_csv(url_2)
data_3 = pd.read_csv(url_3)
data_4 = pd.read_csv(url_4)
data_5 = pd.read_csv(url_5)
data_6 = pd.read_csv(url_6)
data_7 = pd.read_csv(url_7)
data_8 = pd.read_csv(url_8)
data_9 = pd.read_csv(url_9)
data_10 = pd.read_csv(url_10)
data_11 = pd.read_csv(url_11)
data_12 = pd.read_csv(url_12)
data_13 = pd.read_csv(url_13)
data_14 = pd.read_csv(url_14)
data_15 = pd.read_csv(url_15)
data_16 = pd.read_csv(url_16)
data_17 = pd.read_csv(url_17)
data_18 = pd.read_csv(url_18)
data_19 = pd.read_csv(url_19)
data_20 = pd.read_csv(url_20)



from matplotlib import rc, font_manager
rc('font',family = "NanumGothic") #나눔고딕으로 한글 고정

df_1 = pd.DataFrame(data_1,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_1.boxplot(column = '지역', by=['PM10','PM25'])

df_2 = pd.DataFrame(data_2,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_2.boxplot(column = '지역', by=['PM10','PM25'])

df_3 = pd.DataFrame(data_3,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_3.boxplot(column = '지역', by=['PM10','PM25'])

df_4 = pd.DataFrame(data_4,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_4.boxplot(column = '지역', by=['PM10','PM25'])

df_5 = pd.DataFrame(data_5,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_5.boxplot(column = '지역', by=['PM10','PM25'])

df_6 = pd.DataFrame(data_6,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_6.boxplot(column = '지역', by=['PM10','PM25'])

df_7 = pd.DataFrame(data_7,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_7.boxplot(column = '지역', by=['PM10','PM25'])

df_8 = pd.DataFrame(data_8,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_8.boxplot(column = '지역', by=['PM10','PM25'])

df_9 = pd.DataFrame(data_9,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_9.boxplot(column = '지역', by=['PM10','PM25'])

df_10 = pd.DataFrame(data_10,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_10.boxplot(column = '지역', by=['PM10','PM25'])

df_11 = pd.DataFrame(data_11,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_11.boxplot(column = '지역', by=['PM10','PM25'])

df_12 = pd.DataFrame(data_12,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_12.boxplot(column = '지역', by=['PM10','PM25'])

df_13 = pd.DataFrame(data_13,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_13.boxplot(column = '지역', by=['PM10','PM25'])

df_14 = pd.DataFrame(data_14,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_14.boxplot(column = '지역', by=['PM10','PM25'])

df_15 = pd.DataFrame(data_15,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_15.boxplot(column = '지역', by=['PM10','PM25'])

df_16 = pd.DataFrame(data_16,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_16.boxplot(column = '지역', by=['PM10','PM25'])

df_17 = pd.DataFrame(data_17,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_17.boxplot(column = '지역', by=['PM10','PM25'])

df_18 = pd.DataFrame(data_18,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_18.boxplot(column = '지역', by=['PM10','PM25'])

df_19 = pd.DataFrame(data_19,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_19.boxplot(column = '지역', by=['PM10','PM25'])

df_20 = pd.DataFrame(data_20,columns =['지역' ,'PM10','PM25'])
mpl.rc('font',family='AppleGothic')
df_20.boxplot(column = '지역', by=['PM10','PM25'])
# Out:
#        지역   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  PM25  \
# 0  강원 강릉시  632132  옥천동  2015010101  0.005  0.6  0.025  0.005  33.0  11.0
# 1  강원 강릉시  632132  옥천동  2015010102  0.006  0.6  0.023  0.005  35.0   8.0
# 2  강원 강릉시  632132  옥천동  2015010103  0.005  0.7  0.022  0.005  37.0   9.0
# 3  강원 강릉시  632132  옥천동  2015010104  0.006  0.6  0.021  0.005  42.0  11.0
# 4  강원 강릉시  632132  옥천동  2015010105  0.005  0.6  0.021  0.005  47.0   8.0
#
#                           주소
# 0  강원 강릉시 옥천동 327-2(옥천동주민센터)
# 1  강원 강릉시 옥천동 327-2(옥천동주민센터)
# 2  강원 강릉시 옥천동 327-2(옥천동주민센터)
# 3  강원 강릉시 옥천동 327-2(옥천동주민센터)
# 4  강원 강릉시 옥천동 327-2(옥천동주민센터)
